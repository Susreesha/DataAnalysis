# %% [markdown]
# <a href="https://colab.research.google.com/github/Susreesha/DataAnalysis/blob/main/Neon2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_heart = pd.read_csv('/content/Heart_Attack_Risk_Updated.csv')
df_patient = pd.read_excel('/content/Patient_Height.xlsx')

# %%
df_heart
# Out:
#     Patient ID   Age  Gender  Cholesterol  Heart Rate       Diet        BMI  \
# 0            1    67    Male          208        72.0    Average  31.251233
# 1            1    67    Male          208        72.0    Average  27.194973
# 2            2    21    Male          389        98.0  Unhealthy  28.176571
# 3            3    21  Female          324        72.0    Healthy  36.464704
# 4            4    84    Male          383        73.0    Average  21.809144
# 5            5    66    Male          318         NaN  Unhealthy  20.146839
# 6            6    54  Female          297        48.0  Unhealthy  28.885811
# 7            7    90    Male          358        84.0    Healthy  22.221862
# 8            8    84    Male          150       107.0    Average        NaN
# 9            9  1000    Male          145        68.0    Average  22.558917
# 10          10    43  Female          248        55.0  Unhealthy  35.809901
#
#    Country    Continent Heart Risk Score Category
# ...

# %%
df_heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient ID                 11 non-null     int64
#  1   Age                        11 non-null     int64
#  2   Gender                     11 non-null     object
#  3   Cholesterol                11 non-null     int64
#  4   Heart Rate                 10 non-null     float64
#  5   Diet                       11 non-null     object
#  6   BMI                        10 non-null     float64
#  7   Country                    11 non-null     object
#  8   Continent                  11 non-null     object
#  9   Heart Risk Score Category  11 non-null     object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 1008.0+ bytes

# %%
df_heart.head(5)
# Out:
#    Patient ID  Age  Gender  Cholesterol  Heart Rate       Diet        BMI  \
# 0           1   67    Male          208        72.0    Average  31.251233
# 1           1   67    Male          208        72.0    Average  27.194973
# 2           2   21    Male          389        98.0  Unhealthy  28.176571
# 3           3   21  Female          324        72.0    Healthy  36.464704
# 4           4   84    Male          383        73.0    Average  21.809144
#
#   Country    Continent Heart Risk Score Category
# 0      c1  continent 1                  Low Risk
# 1      c1  continent 1                  Low Risk
# 2      c2  continent 2                 High Risk
# 3      c3  continent 3                  Low Risk
# 4      c2  continent 2              Average Risk

# %%
df_heart.tail(5)
# Out:
#     Patient ID   Age  Gender  Cholesterol  Heart Rate       Diet        BMI  \
# 6            6    54  Female          297        48.0  Unhealthy  28.885811
# 7            7    90    Male          358        84.0    Healthy  22.221862
# 8            8    84    Male          150       107.0    Average        NaN
# 9            9  1000    Male          145        68.0    Average  22.558917
# 10          10    43  Female          248        55.0  Unhealthy  35.809901
#
#    Country    Continent Heart Risk Score Category
# 6       c5  continent 3                  Low Risk
# 7       c2  continent 2                  Low Risk
# 8       c6  continent 4                  Low Risk
# 9       c7  continent 1                  Low Risk
# 10      c6  continent 4                  Low Risk

# %%
print(df_heart.columns)
# Out:
# Index(['Patient ID', 'Age', 'Gender', 'Cholesterol', 'Heart Rate', 'Diet',
#        'BMI', 'Country', 'Continent', 'Heart Risk Score Category'],
#       dtype='object')

# %%
series_age = df_heart['Age']
series_age
# Out:
# 0       67
# 1       67
# 2       21
# 3       21
# 4       84
# 5       66
# 6       54
# 7       90
# 8       84
# 9     1000
# 10      43
# Name: Age, dtype: int64

# %%
df_heart[['Age','Gender','Heart Risk Score Category']]
# Out:
#      Age  Gender Heart Risk Score Category
# 0     67    Male                  Low Risk
# 1     67    Male                  Low Risk
# 2     21    Male                 High Risk
# 3     21  Female                  Low Risk
# 4     84    Male              Average Risk
# 5     66    Male              Average Risk
# 6     54  Female                  Low Risk
# 7     90    Male                  Low Risk
# 8     84    Male                  Low Risk
# 9   1000    Male                  Low Risk
# 10    43  Female                  Low Risk

# %%
df_heart.iloc[:,5]
# Out:
# 0       Average
# 1       Average
# 2     Unhealthy
# 3       Healthy
# 4       Average
# 5     Unhealthy
# 6     Unhealthy
# 7       Healthy
# 8       Average
# 9       Average
# 10    Unhealthy
# Name: Diet, dtype: object

# %%
df_heart.iloc[5,5]
# Out:
# 'Unhealthy'
